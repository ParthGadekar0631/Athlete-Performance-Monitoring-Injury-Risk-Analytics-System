# %% [markdown]
# # Baseball Athlete Monitoring Exploratory Analysis
#
# Run the pipeline first, then use this notebook to inspect workload, readiness, ACWR, and risk outputs.

# %%
import pandas as pd
features = pd.read_csv('../data/analytics/athlete_features.csv')
features.head()

# %%
features.groupby('position')[['workload_score', 'readiness_score', 'acwr', 'injury_risk_score']].mean().round(2)
